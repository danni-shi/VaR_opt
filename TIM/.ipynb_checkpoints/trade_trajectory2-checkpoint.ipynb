# %%
import numpy as np
import pandas as pd
import pickle
from matplotlib import pyplot as plt
import os

# %%
# Base directory
base_dir = '/nfs/home/dannis/AC-model/TIM_fix_mean_results/theta_1.41e-06_alpha_27.93'

# Storage for all trade data
all_trades = {}
file_info = []

# Iterate through subfolders
for filename in os.listdir(base_dir):
    
    if filename.endswith('.pkl'):
        file_path = os.path.join(base_dir, filename)
        print(f"  Reading file: {filename}")
        
        try:
            with open(file_path, 'rb') as f:
                data = pickle.load(f)
            
            
            # Extract key info from filename and subfolder
            key = f"{filename}"
            all_trades[key] = data['trades']
            file_info.append({
                'key': key,
                'filename': filename,
                'trades': data['trades'],
                'mip_gap': data.get('mip_gap', None),
                'status': data.get('status', 'unknown'),
            })
                
        except Exception as e:
            print(f"    Error reading {filename}: {e}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 9
#       6 file_info = []
#       8 # Iterate through subfolders
# ----> 9 for filename in os.listdir(base_dir):
#      11     if filename.endswith('.pkl'):
#      12         file_path = os.path.join(base_dir, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/nfs/home/dannis/AC-model/TIM_fix_mean_results/theta_1.41e-06_alpha_27.93'

# %%
# Base directory
base_dir = '/nfs/home/dannis/AC-model/TIM_fix_mean_results'


# Storage for all trade data
all_trades = {}
file_info = []

# Iterate through subfolders
for subfolder in os.listdir(base_dir):
    subfolder_path = os.path.join(base_dir, subfolder)
    if os.path.isdir(subfolder_path):
        print(f"Processing subfolder: {subfolder}")
        
        # Iterate through files in subfolder
        for filename in os.listdir(subfolder_path):
            if filename.endswith('.pkl'):
                file_path = os.path.join(subfolder_path, filename)
                print(f"  Reading file: {filename}")
                
                try:
                    with open(file_path, 'rb') as f:
                        data = pickle.load(f)
                    
                    
                    # Extract key info from filename and subfolder
                    key = f"{subfolder}_{filename}"
                    all_trades[key] = data['trades']
                    file_info.append({
                        'key': key,
                        'subfolder': subfolder,
                        'filename': filename,
                        'trades': data['trades'],
                        'status': data.get('status', 'unknown'),
                        'mip_gap': data.get('mip_gap', None),
                    })
                        
                except Exception as e:
                    print(f"    Error reading {filename}: {e}")
# Out:
# Processing subfolder: 2_theta_1.349766e-06_alpha_4.397102
#   Reading file: opt_1.349766e-06_24.pkl
#   Reading file: opt_1.349766e-06_26.pkl
#   Reading file: opt_1.349766e-06_12.pkl
#   Reading file: opt_1.349766e-06_29.pkl
#   Reading file: opt_1.349766e-06_21.pkl
#   Reading file: opt_1.349766e-06_22.pkl
#   Reading file: opt_1.349766e-06_13.pkl
#   Reading file: opt_1.349766e-06_19.pkl
#   Reading file: opt_1.349766e-06_20.pkl
#   Reading file: opt_1.349766e-06_23.pkl
#   Reading file: opt_1.349766e-06_17.pkl
#   Reading file: opt_1.349766e-06_14.pkl
#   Reading file: opt_1.349766e-06_25.pkl
#   Reading file: opt_1.349766e-06_30.pkl
#   Reading file: opt_1.349766e-06_18.pkl
#   Reading file: opt_1.349766e-06_16.pkl
#   Reading file: opt_1.349766e-06_28.pkl
#   Reading file: opt_1.349766e-06_27.pkl
#   Reading file: opt_1.349766e-06_31.pkl
#   Reading file: opt_1.349766e-06_15.pkl
#   Reading file: opt_1.349766e-06_11.pkl
# Processing subfolder: fixed_mean_3
# Processing subfolder: 3_theta_5.268546e-07_alpha_6.088576
#   Reading file: opt_5.268546e-07_27.pkl
#   Reading file: opt_5.268546e-07_14.pkl
#   Reading file: opt_5.268546e-07_11.pkl
#   Reading file: opt_5.268546e-07_30.pkl
#   Reading file: opt_5.268546e-07_22.pkl
#   Reading file: opt_5.268546e-07_23.pkl
#   Reading file: opt_5.268546e-07_13.pkl
#   Reading file: opt_5.268546e-07_19.pkl
#   Reading file: opt_5.268546e-07_28.pkl
#   Reading file: opt_5.268546e-07_18.pkl
#   Reading file: opt_5.268546e-07_20.pkl
#   Reading file: opt_5.268546e-07_31.pkl
#   Reading file: opt_5.268546e-07_24.pkl
#   Reading file: opt_5.268546e-07_26.pkl
#   Reading file: opt_5.268546e-07_17.pkl
#   Reading file: opt_5.268546e-07_29.pkl
#   Reading file: opt_5.268546e-07_15.pkl
#   Reading file: opt_5.268546e-07_12.pkl
#   Reading file: opt_5.268546e-07_16.pkl
#   Reading file: opt_5.268546e-07_25.pkl
#   Reading file: opt_5.268546e-07_21.pkl
# Processing subfolder: 0_theta_1.41e-06_alpha_27.93
#   Reading file: opt_1.41e-06_4.pkl
#   Reading file: opt_1.41e-06_3.pkl
#   Reading file: opt_1.41e-06_1.pkl
#   Reading file: opt_1.41e-06_2.pkl
#   Reading file: opt_1.41e-06_9.pkl
#   Reading file: opt_1.41e-06_8.pkl
#   Reading file: opt_1.41e-06_7.pkl
#   Reading file: opt_1.41e-06_10.pkl
#   Reading file: opt_1.41e-06_6.pkl
#   Reading file: opt_1.41e-06_5.pkl
# Processing subfolder: fixed_mean_0
# Processing subfolder: 1_theta_1.91e-06_alpha_9.24
#   Reading file: opt_1.91e-06_2.pkl
#   Reading file: opt_1.91e-06_6.pkl
#   Reading file: opt_1.91e-06_1.pkl
#   Reading file: opt_1.91e-06_5.pkl
#   Reading file: opt_1.91e-06_4.pkl
#   Reading file: opt_1.91e-06_3.pkl
#   Reading file: opt_1.91e-06_8.pkl
#   Reading file: opt_1.91e-06_10.pkl
#   Reading file: opt_1.91e-06_7.pkl
#   Reading file: opt_1.91e-06_9.pkl

# %%
data_rows = []

for i, info in enumerate(file_info):
    ind = int(info['subfolder'].split('_')[0])
    if ind <= 1:
        continue
    theta_var = float(info['subfolder'].split('_')[2])
    seed = info['filename'].split('_')[-1].split('.')[0]
    trades = np.array(info['trades'])
        
    # Create a row with ntrades, seed, and each trade element as separate columns
    row = {
        'theta_var': theta_var,
        'seed': seed,
        'mip_gap': info.get('mip_gap', None),
        'ind': ind
    }
    
    # Add each trade element as a separate column (trade_0, trade_1, ..., trade_10)
    for j, trade in enumerate(trades):
        row[f'trade_{j}'] = trade
    
    data_rows.append(row)

# Create DataFrame
df = pd.DataFrame(data_rows)

# %%
df_inventory = 1000 - df.filter(like='trade_').cumsum(axis=1)
df_inventory.columns = [(i + 1) for i in range(df_inventory.shape[1])]
df_inventory[0] = 1000

# %%
groups = df_inventory.groupby(df['theta_var'])

plt.figure(figsize=(12, 8))


for theta_var, group in groups:
    
    
    # Calculate mean and standard error for each trade column
    means = []
    std_errors = []
    
    for col in sorted(df_inventory.columns):
        mean_val = group[col].mean()
        std_val = group[col].std()
        n_samples = len(group)
        std_error = std_val / np.sqrt(n_samples)
        
        means.append(mean_val)
        std_errors.append(std_error)
    
    means = np.array(means)
    std_errors = np.array(std_errors)
    x = np.arange(len(means))  # Trade steps 0 to 10

    # Plot mean trajectory
    plt.plot(x, means, marker='o', label=f'theta_var={theta_var:.3g}', linewidth=2)
    
    # Add standard error bands
    plt.fill_between(x, means - std_errors, means + std_errors, alpha=0.2)

plt.xlabel('Trade Step')
plt.ylabel('Trade Value')
plt.title('Mean Trade Trajectory with Standard Error by theta_var')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
